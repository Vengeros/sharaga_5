# %%
from datetime import date, datetime, time, timedelta
from geopy.distance import geodesic
from pyspark.sql import SparkSession
from pyspark.sql import SparkSession, DataFrame
from pyspark.sql.functions import expr, hour, count
from pyspark.sql.window import Window
import json
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd 
import random


GEO_POINTS_DATA_PATH = 'data/London_postcodes.csv'
NUM_RECORDS = 1_000_000

# %% [markdown]
# # Generate Rides

# %%
def calc_cost(x):
    start_time = x['start_time'].time()
    distance = x['distance']
    price = 1
    price_peak = 2
    
    if time(8,0,0) < start_time < time(11,0,0) or time(15,0,0) < start_time < time(22,0,0):
        cost = distance * price_peak
    else:
        cost = distance * price
        
    return cost


def calc_road_time(x):
    start_time = x['start_time'].time()
    distance = x['distance']
    speed = 60
    speed_peak = 40

    if time(8,0,0) < start_time < time(11,0,0) or time(15,0,0) < start_time < time(22,0,0):
        road_time = timedelta(distance/speed/24)
    else:
        road_time = timedelta(distance/speed_peak/24)
        
    return road_time

# %%
geo_points = pd.read_csv(GEO_POINTS_DATA_PATH, low_memory=False)
rides = pd.DataFrame(columns=[
    'rider_id',
    'client_id',
    'start', 
    'start_latitude', 
    'start_longtitude',
    'end',
    'end_latitude', 
    'end_longtitude',
    'start_time',
    'end_time',
    'cost',
    'rider_score',
    'rider_fitback',
    'text',
    'client_score',
    'client_fitback',
])

# %%
riders_pull = np.arange(1000, 4000)
rides['rider_id'] = np.random.choice(riders_pull, NUM_RECORDS)
rides['rider_score' ] = np.random.choice((None,None,None,None,None,1,2,3,4,5), NUM_RECORDS)

# %%
clients_pull = np.arange(1000, 7000)
rides['client_id'] = np.random.choice(clients_pull, NUM_RECORDS)
rides['client_score' ] = np.random.choice((None,None,None,None,None,1,2,3,4,5), NUM_RECORDS)

# %%
start_pull = geo_points[['Postcode', 'Latitude', 'Longitude']].sample(n=NUM_RECORDS, replace=True).reset_index(drop=True)
rides[['start', 'start_latitude', 'start_longtitude']] = start_pull

# %%
end_pull = geo_points[['Postcode', 'Latitude', 'Longitude']].sample(n=NUM_RECORDS, replace=True).reset_index(drop=True)
rides[['end', 'end_latitude', 'end_longtitude']] = end_pull

# %%
distance_agg = lambda x: geodesic(
    (x['start_latitude'], x['start_longtitude']), 
    (x['end_latitude'], x['end_longtitude'])).km
rides['distance'] = rides.apply(distance_agg, axis='columns', result_type='reduce')

# %%
time_pull = [
    datetime.combine(date.today(), time(h,m,s))
    for h in range(24) 
    for m in range(60) 
    for s in range(60)
]
rides['start_time'] = np.random.choice(time_pull, NUM_RECORDS)

# %%
rides['cost'] = rides.apply(calc_cost, axis='columns', result_type='reduce')

# %%
rides['road_time'] = rides.apply(calc_road_time, axis='columns', result_type='reduce')

# %%
rides['end_time'] = rides['start_time'] + rides['road_time']

# %%
display(rides)
# Out:
#         rider_id  client_id     start  start_latitude  start_longtitude  \
# 0           3284       2453    E4 7WW       51.633250          0.008156
# 1           1983       2525   W1C 2PW       51.513765         -0.153232
# 2           1688       6331  SW19 8FH       51.417014         -0.213582
# 3           3895       2470   SW4 0XP       51.463241         -0.139336
# 4           2875       2277   W12 6AW       51.511059         -0.220758
# ...          ...        ...       ...             ...               ...
# 999995      2684       4855    N4 2UT       51.568646         -0.097533
# 999996      2460       5165    N6 4JS       51.574668         -0.163407
# 999997      2252       4201   SW8 4UN       51.474559         -0.141410
# 999998      1554       3596   HA9 0AN       51.561422         -0.273515
# 999999      2747       6743    W2 1TU       51.514399         -0.174796
#
#              end  end_latitude  end_longtitude          start_time  \
# 0       EC2Y 9DP     51.518267       -0.089587 2020-12-24 21:40:25
# 1        UB4 9LD     51.532188       -0.405000 2020-12-24 14:51:35
# 2       NW1W 7SP     51.530785       -0.135430 2020-12-24 08:44:51
# 3       SW18 3WJ     51.448231       -0.191526 2020-12-24 13:58:50
# 4        CR2 6WF     51.375716       -0.091863 2020-12-24 13:04:09
# ...          ...           ...             ...                 ...
# 999995  SE18 5TP     51.493967        0.041228 2020-12-24 12:30:43
# 999996   W1R 0DD     51.514151       -0.145232 2020-12-24 07:44:15
# 999997   BR3 1GL     51.399286       -0.049249 2020-12-24 14:31:05
# 999998   HA1 3PB     51.561626       -0.343853 2020-12-24 17:51:15
# 999999   CR2 4NG     51.328725       -0.134064 2020-12-24 11:06:23
#
#                          end_time       cost rider_score rider_fitback text  \
# 0      2020-12-24 21:54:53.600071  28.953336        None           NaN  NaN
# 1      2020-12-24 15:17:58.451304  17.593903        None           NaN  NaN
# 2      2020-12-24 08:58:37.403628  27.546788        None           NaN  NaN
# 3      2020-12-24 14:04:49.418417   3.993538        None           NaN  NaN
# 4      2020-12-24 13:30:26.051764  17.522797        None           NaN  NaN
# ...                           ...        ...         ...           ...  ...
# 999995 2020-12-24 12:49:47.636302  12.718181           4           NaN  NaN
# 999996 2020-12-24 07:54:31.507239   6.850080        None           NaN  NaN
# 999997 2020-12-24 14:46:54.077988  10.545311           2           NaN  NaN
# 999998 2020-12-24 17:56:07.666827   9.755561        None           NaN  NaN
# 999999 2020-12-24 11:37:39.572555  20.850806        None           NaN  NaN
#
#        client_score client_fitback   distance              road_time
# 0              None            NaN  14.476668 0 days 00:14:28.600071
# 1              None            NaN  17.593903 0 days 00:26:23.451304
# 2              None            NaN  13.773394 0 days 00:13:46.403628
# 3              None            NaN   3.993538 0 days 00:05:59.418417
# 4                 4            NaN  17.522797 0 days 00:26:17.051764
# ...             ...            ...        ...                    ...
# 999995            5            NaN  12.718181 0 days 00:19:04.636302
# 999996            1            NaN   6.850080 0 days 00:10:16.507239
# 999997         None            NaN  10.545311 0 days 00:15:49.077988
# 999998            5            NaN   4.877780 0 days 00:04:52.666827
# 999999            3            NaN  20.850806 0 days 00:31:16.572555
#
# [1000000 rows x 18 columns]

# %% [markdown]
# # Map Reduce

# %%
def top_k_drivers(df: DataFrame, limit: int):
    return df.where(df.rider_score.isNotNull()) \
    .orderBy(df.rider_score, ascending=False) \
    .select('rider_id', 'rider_score') \
    .limit(limit) \
    .rdd.map(lambda row: {'rider_id': row[0], 'rider_score': row[1]})

def top_k_clients(df: DataFrame, limit: int):
    return df.where(df.client_score.isNotNull()) \
    .orderBy(df.client_score, ascending=False) \
    .select('client_id', 'client_score') \
    .limit(limit) \
    .rdd.map(lambda row: {'client_id': row[0], 'client_score': row[1]})


def worst_drivers(df: DataFrame, limit: int):
    return df.where(df.rider_score < 3.5) \
    .orderBy(df.rider_score, ascending=True) \
    .select('rider_id', 'rider_score') \
    .limit(limit) \
    .rdd.map(lambda row: {'rider_id': row[0], 'rider_score': row[1]})

# %%
spark = SparkSession.builder.getOrCreate()

df = spark.createDataFrame(rides)

# %%
top_k_drivers(df, 100).collect()
# Out:
# [{'rider_id': 1401, 'rider_score': 5},
#  {'rider_id': 3351, 'rider_score': 5},
#  {'rider_id': 2877, 'rider_score': 5},
#  {'rider_id': 1719, 'rider_score': 5},
#  {'rider_id': 3856, 'rider_score': 5},
#  {'rider_id': 1865, 'rider_score': 5},
#  {'rider_id': 2259, 'rider_score': 5},
#  {'rider_id': 3657, 'rider_score': 5},
#  {'rider_id': 3604, 'rider_score': 5},
#  {'rider_id': 2898, 'rider_score': 5},
#  {'rider_id': 2655, 'rider_score': 5},
#  {'rider_id': 3062, 'rider_score': 5},
#  {'rider_id': 2761, 'rider_score': 5},
#  {'rider_id': 2225, 'rider_score': 5},
#  {'rider_id': 3338, 'rider_score': 5},
#  {'rider_id': 1002, 'rider_score': 5},
#  {'rider_id': 1116, 'rider_score': 5},
#  {'rider_id': 3068, 'rider_score': 5},
#  {'rider_id': 3504, 'rider_score': 5},
#  {'rider_id': 2437, 'rider_score': 5},
#  {'rider_id': 1697, 'rider_score': 5},
#  {'rider_id': 2362, 'rider_score': 5},
#  {'rider_id': 1579, 'rider_score': 5},
#  {'rider_id': 2400, 'rider_score': 5},
#  {'rider_id': 1772, 'rider_score': 5},
#  {'rider_id': 1944, 'rider_score': 5},
#  {'rider_id': 1991, 'rider_score': 5},
#  {'rider_id': 3284, 'rider_score': 5},
#  {'rider_id': 3463, 'rider_score': 5},
#  {'rider_id': 1992, 'rider_score': 5},
#  {'rider_id': 3065, 'rider_score': 5},
#  {'rider_id': 2028, 'rider_score': 5},
#  {'rider_id': 2830, 'rider_score': 5},
#  {'rider_id': 1408, 'rider_score': 5},
#  {'rider_id': 1611, 'rider_score': 5},
#  {'rider_id': 3689, 'rider_score': 5},
#  {'rider_id': 3634, 'rider_score': 5},
#  {'rider_id': 1167, 'rider_score': 5},
#  {'rider_id': 3054, 'rider_score': 5},
#  {'rider_id': 1351, 'rider_score': 5},
#  {'rider_id': 1695, 'rider_score': 5},
#  {'rider_id': 3593, 'rider_score': 5},
#  {'rider_id': 1200, 'rider_score': 5},
#  {'rider_id': 3772, 'rider_score': 5},
#  {'rider_id': 1218, 'rider_score': 5},
#  {'rider_id': 3980, 'rider_score': 5},
#  {'rider_id': 3231, 'rider_score': 5},
#  {'rider_id': 1001, 'rider_score': 5},
#  {'rider_id': 1183, 'rider_score': 5},
#  {'rider_id': 1934, 'rider_score': 5},
#  {'rider_id': 2375, 'rider_score': 5},
#  {'rider_id': 3552, 'rider_score': 5},
#  {'rider_id': 3208, 'rider_score': 5},
#  {'rider_id': 3240, 'rider_score': 5},
#  {'rider_id': 3324, 'rider_score': 5},
#  {'rider_id': 3256, 'rider_score': 5},
#  {'rider_id': 2710, 'rider_score': 5},
#  {'rider_id': 3199, 'rider_score': 5},
#  {'rider_id': 1971, 'rider_score': 5},
#  {'rider_id': 1144, 'rider_score': 5},
#  {'rider_id': 2716, 'rider_score': 5},
#  {'rider_id': 1808, 'rider_score': 5},
#  {'rider_id': 2795, 'rider_score': 5},
#  {'rider_id': 1029, 'rider_score': 5},
#  {'rider_id': 2142, 'rider_score': 5},
#  {'rider_id': 3151, 'rider_score': 5},
#  {'rider_id': 3122, 'rider_score': 5},
#  {'rider_id': 3495, 'rider_score': 5},
#  {'rider_id': 1842, 'rider_score': 5},
#  {'rider_id': 1368, 'rider_score': 5},
#  {'rider_id': 1197, 'rider_score': 5},
#  {'rider_id': 2637, 'rider_score': 5},
#  {'rider_id': 1750, 'rider_score': 5},
#  {'rider_id': 3953, 'rider_score': 5},
#  {'rider_id': 1418, 'rider_score': 5},
#  {'rider_id': 3954, 'rider_score': 5},
#  {'rider_id': 2890, 'rider_score': 5},
#  {'rider_id': 3426, 'rider_score': 5},
#  {'rider_id': 1615, 'rider_score': 5},
#  {'rider_id': 2574, 'rider_score': 5},
#  {'rider_id': 2044, 'rider_score': 5},
#  {'rider_id': 1062, 'rider_score': 5},
#  {'rider_id': 3378, 'rider_score': 5},
#  {'rider_id': 1114, 'rider_score': 5},
#  {'rider_id': 1139, 'rider_score': 5},
#  {'rider_id': 1554, 'rider_score': 5},
#  {'rider_id': 3361, 'rider_score': 5},
#  {'rider_id': 2905, 'rider_score': 5},
#  {'rider_id': 2933, 'rider_score': 5},
#  {'rider_id': 3312, 'rider_score': 5},
#  {'rider_id': 2024, 'rider_score': 5},
#  {'rider_id': 3205, 'rider_score': 5},
#  {'rider_id': 3594, 'rider_score': 5},
#  {'rider_id': 3702, 'rider_score': 5},
#  {'rider_id': 2707, 'rider_score': 5},
#  {'rider_id': 2265, 'rider_score': 5},
#  {'rider_id': 3296, 'rider_score': 5},
#  {'rider_id': 1144, 'rider_score': 5},
#  {'rider_id': 1285, 'rider_score': 5},
#  {'rider_id': 1181, 'rider_score': 5}]

# %%
top_k_clients(df, 50).collect()
# Out:
# [{'client_id': 5248, 'client_score': 5},
#  {'client_id': 2107, 'client_score': 5},
#  {'client_id': 2071, 'client_score': 5},
#  {'client_id': 2172, 'client_score': 5},
#  {'client_id': 4610, 'client_score': 5},
#  {'client_id': 1303, 'client_score': 5},
#  {'client_id': 6071, 'client_score': 5},
#  {'client_id': 3689, 'client_score': 5},
#  {'client_id': 5722, 'client_score': 5},
#  {'client_id': 1059, 'client_score': 5},
#  {'client_id': 6509, 'client_score': 5},
#  {'client_id': 4598, 'client_score': 5},
#  {'client_id': 6212, 'client_score': 5},
#  {'client_id': 4408, 'client_score': 5},
#  {'client_id': 1059, 'client_score': 5},
#  {'client_id': 1607, 'client_score': 5},
#  {'client_id': 2949, 'client_score': 5},
#  {'client_id': 3888, 'client_score': 5},
#  {'client_id': 4951, 'client_score': 5},
#  {'client_id': 2919, 'client_score': 5},
#  {'client_id': 5117, 'client_score': 5},
#  {'client_id': 2028, 'client_score': 5},
#  {'client_id': 6108, 'client_score': 5},
#  {'client_id': 3933, 'client_score': 5},
#  {'client_id': 1724, 'client_score': 5},
#  {'client_id': 5636, 'client_score': 5},
#  {'client_id': 5033, 'client_score': 5},
#  {'client_id': 5553, 'client_score': 5},
#  {'client_id': 1962, 'client_score': 5},
#  {'client_id': 2563, 'client_score': 5},
#  {'client_id': 5782, 'client_score': 5},
#  {'client_id': 3447, 'client_score': 5},
#  {'client_id': 4540, 'client_score': 5},
#  {'client_id': 4733, 'client_score': 5},
#  {'client_id': 2507, 'client_score': 5},
#  {'client_id': 3901, 'client_score': 5},
#  {'client_id': 6409, 'client_score': 5},
#  {'client_id': 1522, 'client_score': 5},
#  {'client_id': 6146, 'client_score': 5},
#  {'client_id': 3624, 'client_score': 5},
#  {'client_id': 6279, 'client_score': 5},
#  {'client_id': 2834, 'client_score': 5},
#  {'client_id': 1082, 'client_score': 5},
#  {'client_id': 4550, 'client_score': 5},
#  {'client_id': 6239, 'client_score': 5},
#  {'client_id': 2627, 'client_score': 5},
#  {'client_id': 4734, 'client_score': 5},
#  {'client_id': 3363, 'client_score': 5},
#  {'client_id': 6272, 'client_score': 5},
#  {'client_id': 1623, 'client_score': 5}]

# %%
worst_drivers(df, 200).collect()

# %%
# Out:
# [{'rider_id': 3836, 'rider_score': 1},
#  {'rider_id': 1290, 'rider_score': 1},
#  {'rider_id': 3547, 'rider_score': 1},
#  {'rider_id': 1187, 'rider_score': 1},
#  {'rider_id': 2791, 'rider_score': 1},
#  {'rider_id': 3924, 'rider_score': 1},
#  {'rider_id': 2011, 'rider_score': 1},
#  {'rider_id': 2045, 'rider_score': 1},
#  {'rider_id': 3206, 'rider_score': 1},
#  {'rider_id': 3035, 'rider_score': 1},
#  {'rider_id': 3970, 'rider_score': 1},
#  {'rider_id': 2505, 'rider_score': 1},
#  {'rider_id': 2574, 'rider_score': 1},
#  {'rider_id': 1805, 'rider_score': 1},
#  {'rider_id': 3070, 'rider_score': 1},
#  {'rider_id': 2577, 'rider_score': 1},
#  {'rider_id': 3428, 'rider_score': 1},
#  {'rider_id': 3810, 'rider_score': 1},
#  {'rider_id': 1773, 'rider_score': 1},
#  {'rider_id': 2972, 'rider_score': 1},
#  {'rider_id': 2379, 'rider_score': 1},
#  {'rider_id': 3305, 'rider_score': 1},
#  {'rider_id': 1149, 'rider_score': 1},
#  {'rider_id': 3217, 'rider_score': 1},
#  {'rider_id': 2892, 'rider_score': 1},
#  {'rider_id': 1848, 'rider_score': 1},
#  {'rider_id': 3505, 'rider_score': 1},
#  {'rider_id': 3134, 'rider_score': 1},
#  {'rider_id': 3814, 'rider_score': 1},
#  {'rider_id': 3795, 'rider_score': 1},
#  {'rider_id': 3637, 'rider_score': 1},
#  {'rider_id': 2365, 'rider_score': 1},
#  {'rider_id': 3747, 'rider_score': 1},
#  {'rider_id': 2719, 'rider_score': 1},
#  {'rider_id': 2886, 'rider_score': 1},
#  {'rider_id': 3088, 'rider_score': 1},
#  {'rider_id': 2277, 'rider_score': 1},
#  {'rider_id': 2241, 'rider_score': 1},
#  {'rider_id': 2630, 'rider_score': 1},
#  {'rider_id': 3099, 'rider_score': 1},
#  {'rider_id': 1903, 'rider_score': 1},
#  {'rider_id': 3092, 'rider_score': 1},
#  {'rider_id': 2238, 'rider_score': 1},
#  {'rider_id': 2777, 'rider_score': 1},
#  {'rider_id': 1158, 'rider_score': 1},
#  {'rider_id': 2690, 'rider_score': 1},
#  {'rider_id': 2117, 'rider_score': 1},
#  {'rider_id': 3197, 'rider_score': 1},
#  {'rider_id': 3104, 'rider_score': 1},
#  {'rider_id': 1355, 'rider_score': 1},
#  {'rider_id': 2208, 'rider_score': 1},
#  {'rider_id': 3305, 'rider_score': 1},
#  {'rider_id': 1493, 'rider_score': 1},
#  {'rider_id': 3579, 'rider_score': 1},
#  {'rider_id': 2542, 'rider_score': 1},
#  {'rider_id': 3148, 'rider_score': 1},
#  {'rider_id': 1910, 'rider_score': 1},
#  {'rider_id': 2771, 'rider_score': 1},
#  {'rider_id': 3040, 'rider_score': 1},
#  {'rider_id': 1717, 'rider_score': 1},
#  {'rider_id': 1263, 'rider_score': 1},
#  {'rider_id': 2715, 'rider_score': 1},
#  {'rider_id': 2208, 'rider_score': 1},
#  {'rider_id': 3076, 'rider_score': 1},
#  {'rider_id': 3275, 'rider_score': 1},
#  {'rider_id': 2600, 'rider_score': 1},
#  {'rider_id': 3559, 'rider_score': 1},
#  {'rider_id': 2446, 'rider_score': 1},
#  {'rider_id': 1857, 'rider_score': 1},
#  {'rider_id': 3339, 'rider_score': 1},
#  {'rider_id': 2105, 'rider_score': 1},
#  {'rider_id': 2185, 'rider_score': 1},
#  {'rider_id': 1043, 'rider_score': 1},
#  {'rider_id': 3548, 'rider_score': 1},
#  {'rider_id': 2643, 'rider_score': 1},
#  {'rider_id': 3285, 'rider_score': 1},
#  {'rider_id': 2504, 'rider_score': 1},
#  {'rider_id': 1207, 'rider_score': 1},
#  {'rider_id': 2311, 'rider_score': 1},
#  {'rider_id': 3027, 'rider_score': 1},
#  {'rider_id': 1493, 'rider_score': 1},
#  {'rider_id': 2712, 'rider_score': 1},
#  {'rider_id': 2031, 'rider_score': 1},
#  {'rider_id': 2017, 'rider_score': 1},
#  {'rider_id': 1265, 'rider_score': 1},
#  {'rider_id': 2860, 'rider_score': 1},
#  {'rider_id': 3594, 'rider_score': 1},
#  {'rider_id': 3596, 'rider_score': 1},
#  {'rider_id': 2157, 'rider_score': 1},
#  {'rider_id': 2044, 'rider_score': 1},
#  {'rider_id': 3737, 'rider_score': 1},
#  {'rider_id': 3890, 'rider_score': 1},
#  {'rider_id': 3587, 'rider_score': 1},
#  {'rider_id': 1158, 'rider_score': 1},
#  {'rider_id': 2936, 'rider_score': 1},
#  {'rider_id': 2681, 'rider_score': 1},
#  {'rider_id': 2390, 'rider_score': 1},
#  {'rider_id': 1569, 'rider_score': 1},
#  {'rider_id': 3824, 'rider_score': 1},
#  {'rider_id': 3979, 'rider_score': 1},
#  {'rider_id': 3599, 'rider_score': 1},
#  {'rider_id': 2501, 'rider_score': 1},
#  {'rider_id': 3138, 'rider_score': 1},
#  {'rider_id': 1940, 'rider_score': 1},
#  {'rider_id': 1982, 'rider_score': 1},
#  {'rider_id': 1665, 'rider_score': 1},
#  {'rider_id': 2302, 'rider_score': 1},
#  {'rider_id': 2514, 'rider_score': 1},
#  {'rider_id': 3974, 'rider_score': 1},
#  {'rider_id': 3177, 'rider_score': 1},
#  {'rider_id': 1663, 'rider_score': 1},
#  {'rider_id': 1394, 'rider_score': 1},
#  {'rider_id': 1485, 'rider_score': 1},
#  {'rider_id': 3098, 'rider_score': 1},
#  {'rider_id': 1191, 'rider_score': 1},
#  {'rider_id': 2192, 'rider_score': 1},
#  {'rider_id': 2718, 'rider_score': 1},
#  {'rider_id': 2849, 'rider_score': 1},
#  {'rider_id': 3111, 'rider_score': 1},
#  {'rider_id': 2474, 'rider_score': 1},
#  {'rider_id': 1271, 'rider_score': 1},
#  {'rider_id': 2146, 'rider_score': 1},
#  {'rider_id': 1847, 'rider_score': 1},
#  {'rider_id': 1251, 'rider_score': 1},
#  {'rider_id': 1253, 'rider_score': 1},
#  {'rider_id': 3127, 'rider_score': 1},
#  {'rider_id': 3301, 'rider_score': 1},
#  {'rider_id': 2603, 'rider_score': 1},
#  {'rider_id': 2714, 'rider_score': 1},
#  {'rider_id': 3020, 'rider_score': 1},
#  {'rider_id': 2853, 'rider_score': 1},
#  {'rider_id': 1649, 'rider_score': 1},
#  {'rider_id': 2590, 'rider_score': 1},
#  {'rider_id': 3489, 'rider_score': 1},
#  {'rider_id': 2028, 'rider_score': 1},
#  {'rider_id': 1284, 'rider_score': 1},
#  {'rider_id': 3634, 'rider_score': 1},
#  {'rider_id': 3899, 'rider_score': 1},
#  {'rider_id': 1075, 'rider_score': 1},
#  {'rider_id': 2351, 'rider_score': 1},
#  {'rider_id': 2786, 'rider_score': 1},
#  {'rider_id': 1842, 'rider_score': 1},
#  {'rider_id': 1453, 'rider_score': 1},
#  {'rider_id': 3545, 'rider_score': 1},
#  {'rider_id': 3686, 'rider_score': 1},
#  {'rider_id': 1659, 'rider_score': 1},
#  {'rider_id': 2878, 'rider_score': 1},
#  {'rider_id': 1639, 'rider_score': 1},
#  {'rider_id': 1764, 'rider_score': 1},
#  {'rider_id': 2923, 'rider_score': 1},
#  {'rider_id': 3018, 'rider_score': 1},
#  {'rider_id': 1230, 'rider_score': 1},
#  {'rider_id': 3149, 'rider_score': 1},
#  {'rider_id': 1171, 'rider_score': 1},
#  {'rider_id': 3162, 'rider_score': 1},
#  {'rider_id': 3028, 'rider_score': 1},
#  {'rider_id': 2286, 'rider_score': 1},
#  {'rider_id': 3902, 'rider_score': 1},
#  {'rider_id': 2120, 'rider_score': 1},
#  {'rider_id': 3331, 'rider_score': 1},
#  {'rider_id': 3430, 'rider_score': 1},
#  {'rider_id': 1359, 'rider_score': 1},
#  {'rider_id': 1285, 'rider_score': 1},
#  {'rider_id': 3683, 'rider_score': 1},
#  {'rider_id': 1345, 'rider_score': 1},
#  {'rider_id': 2205, 'rider_score': 1},
#  {'rider_id': 1635, 'rider_score': 1},
#  {'rider_id': 1832, 'rider_score': 1},
#  {'rider_id': 1031, 'rider_score': 1},
#  {'rider_id': 1354, 'rider_score': 1},
#  {'rider_id': 3164, 'rider_score': 1},
#  {'rider_id': 1939, 'rider_score': 1},
#  {'rider_id': 3351, 'rider_score': 1},
#  {'rider_id': 3477, 'rider_score': 1},
#  {'rider_id': 2154, 'rider_score': 1},
#  {'rider_id': 2086, 'rider_score': 1},
#  {'rider_id': 2471, 'rider_score': 1},
#  {'rider_id': 2325, 'rider_score': 1},
#  {'rider_id': 3835, 'rider_score': 1},
#  {'rider_id': 3463, 'rider_score': 1},
#  {'rider_id': 3880, 'rider_score': 1},
#  {'rider_id': 1350, 'rider_score': 1},
#  {'rider_id': 1736, 'rider_score': 1},
#  {'rider_id': 3170, 'rider_score': 1},
#  {'rider_id': 2195, 'rider_score': 1},
#  {'rider_id': 2938, 'rider_score': 1},
#  {'rider_id': 3117, 'rider_score': 1},
#  {'rider_id': 2786, 'rider_score': 1},
#  {'rider_id': 3429, 'rider_score': 1},
#  {'rider_id': 1415, 'rider_score': 1},
#  {'rider_id': 3579, 'rider_score': 1},
#  {'rider_id': 3595, 'rider_score': 1},
#  {'rider_id': 1035, 'rider_score': 1},
#  {'rider_id': 2725, 'rider_score': 1},
#  {'rider_id': 1570, 'rider_score': 1},
#  {'rider_id': 2939, 'rider_score': 1},
#  {'rider_id': 2307, 'rider_score': 1},
#  {'rider_id': 3190, 'rider_score': 1},
#  {'rider_id': 3677, 'rider_score': 1},
#  {'rider_id': 3515, 'rider_score': 1}]
