# %%
import numpy as np
import pandas as pd
import cv2
from glob import glob
import time

from sklearn.model_selection import train_test_split

# %%
IMG_DIR = glob('./data/*.png')

def rotate_image(image, angle = 90, scale = 1.0):
    h, w = image.shape
    M = cv2.getRotationMatrix2D((w/2, h/2), angle, scale)
    return cv2.warpAffine(image, M, (w, h))

x_prev = np.array([cv2.imread(image) for image in IMG_DIR])
x_prev = np.array([cv2.cvtColor(image, cv2.COLOR_RGB2GRAY) for image in x_prev])
x_prev = np.concatenate((x_prev, np.array([cv2.flip(image, 1) for image in x_prev])))
x = x_prev.copy()
for angle in np.arange(-45, 50, 5):
    x = np.concatenate((x, np.array([rotate_image(image, angle, scale = 1.2) for image in x_prev])))

y_prev = np.array([1 if 'Layer' in image else 0 for image in IMG_DIR])
y = y_prev.copy()
for i in range(x.shape[0]//(y).shape[0] - 1):
    y = np.concatenate((y_prev, y))

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout

# %%
x_train = x_train.reshape(x_train.shape[0], 128, 128, 1)
x_test = x_test.reshape(x_test.shape[0], 128, 128, 1)

# %%
x_train = tf.keras.utils.normalize(x_train, axis=1)  
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
all_results = dict()

# %% [markdown]
# **CNN_2_layers_kernel_3**

# %%
model_1 = Sequential()
model_1.add(Conv2D(filters = 3, kernel_size = (3, 3), padding = 'valid', activation = 'relu', input_shape = (128, 128, 1)))
model_1.add(MaxPooling2D())
model_1.add(Conv2D(filters = 3, kernel_size = (3, 3), padding = 'valid', activation = 'relu'))
model_1.add(MaxPooling2D())
model_1.add(Flatten())
model_1.add(Dense(units = 2, activation = 'softmax'))

model_1.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

tic = time.perf_counter()
history_1 = model_1.fit(x_train, y_train, epochs = 20, validation_data = (x_test, y_test))
toc = time.perf_counter()

all_results['CNN_2_layers_kernel_3'] = {
    'time': toc-tic,
    'accuracy': history_1.history['accuracy'][-1],
    'val_accuracy': history_1.history['val_accuracy'][-1]
}
# Out:
# Epoch 1/20
# 42/42 [==============================] - 3s 64ms/step - loss: 0.6798 - accuracy: 0.6047 - val_loss: 0.6484 - val_accuracy: 0.6277
# Epoch 2/20
# 42/42 [==============================] - 2s 56ms/step - loss: 0.6367 - accuracy: 0.6303 - val_loss: 0.6149 - val_accuracy: 0.6436
# Epoch 3/20
# 42/42 [==============================] - 2s 51ms/step - loss: 0.5923 - accuracy: 0.6706 - val_loss: 0.5551 - val_accuracy: 0.7181
# Epoch 4/20
# 42/42 [==============================] - 2s 59ms/step - loss: 0.5126 - accuracy: 0.7449 - val_loss: 0.5374 - val_accuracy: 0.7216
# Epoch 5/20
# 42/42 [==============================] - 2s 56ms/step - loss: 0.4974 - accuracy: 0.7514 - val_loss: 0.5269 - val_accuracy: 0.7270
# Epoch 6/20
# 42/42 [==============================] - 2s 52ms/step - loss: 0.4907 - accuracy: 0.7482 - val_loss: 0.5284 - val_accuracy: 0.7252
# Epoch 7/20
# 42/42 [==============================] - 2s 57ms/step - loss: 0.4706 - accuracy: 0.7357 - val_loss: 0.5184 - val_accuracy: 0.7305
# Epoch 8/20
# 42/42 [==============================] - 2s 57ms/step - loss: 0.4520 - accuracy: 0.7680 - val_loss: 0.4990 - val_accuracy: 0.7340
# Epoch 9/20
# 42/42 [==============================] - 3s 65ms/step - loss: 0.4128 - accuracy: 0.7986 - val_loss: 0.4869 - val_accuracy: 0.7447
# Epoch 10/20
# 42/42 [==============================] - 3s 84ms/step - loss: 0.4133 - accuracy: 0.7907 - val_loss: 0.4821 - val_accuracy: 0.7535
# Epoch 11/20
# 42/42 [==============================] - 3s 68ms/step - loss: 0.4072 - accuracy: 0.7913 - val_loss: 0.4835 - val_accuracy: 0.7677
# Epoch 12/20
# 42/42 [==============================] - 3s 67ms/step - loss: 0.3665 - accuracy: 0.8081 - val_loss: 0.4599 - val_accuracy: 0.7606
# Epoch 13/20
# 42/42 [==============================] - 3s 69ms/step - loss: 0.3589 - accuracy: 0.8370 - val_loss: 0.4556 - val_accuracy: 0.7730
# Epoch 14/20
# 42/42 [==============================] - 3s 79ms/step - loss: 0.3491 - accuracy: 0.8457 - val_loss: 0.4560 - val_accuracy: 0.7819
# Epoch 15/20
# 42/42 [==============================] - 3s 75ms/step - loss: 0.3276 - accuracy: 0.8516 - val_loss: 0.4348 - val_accuracy: 0.7766
# Epoch 16/20
# 42/42 [==============================] - 3s 81ms/step - loss: 0.2981 - accuracy: 0.8788 - val_loss: 0.4362 - val_accuracy: 0.7961
# Epoch 17/20
# 42/42 [==============================] - 3s 74ms/step - loss: 0.2792 - accuracy: 0.8953 - val_loss: 0.4191 - val_accuracy: 0.8032
# Epoch 18/20
# 42/42 [==============================] - 3s 70ms/step - loss: 0.2782 - accuracy: 0.8909 - val_loss: 0.4093 - val_accuracy: 0.8050
# Epoch 19/20
# 42/42 [==============================] - 2s 57ms/step - loss: 0.2271 - accuracy: 0.9266 - val_loss: 0.3993 - val_accuracy: 0.7996
# Epoch 20/20
# 42/42 [==============================] - 2s 56ms/step - loss: 0.2138 - accuracy: 0.9289 - val_loss: 0.4048 - val_accuracy: 0.8050

# %% [markdown]
# **CNN_3_layers_kernel_3**

# %%
model_2 = Sequential()
model_2.add(Conv2D(filters = 3, kernel_size = (3, 3), padding = 'valid', activation = 'relu', input_shape = (128, 128, 1)))
model_2.add(MaxPooling2D())
model_2.add(Conv2D(filters = 3, kernel_size = (3, 3), padding = 'valid', activation = 'relu'))
model_2.add(MaxPooling2D())
model_2.add(Conv2D(filters = 3, kernel_size = (3, 3), padding = 'valid', activation = 'relu'))
model_2.add(MaxPooling2D())
model_2.add(Flatten())
model_2.add(Dense(units = 2, activation = 'softmax'))

model_2.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
tic = time.perf_counter()
history_2 = model_2.fit(x_train, y_train, epochs = 30, validation_data = (x_test, y_test))
toc = time.perf_counter()

all_results['CNN_3_layers_kernel_3'] = {
    'time': toc-tic,
    'accuracy': history_2.history['accuracy'][-1],
    'val_accuracy': history_2.history['val_accuracy'][-1]
}
# Out:
# Epoch 1/30
# 42/42 [==============================] - 3s 58ms/step - loss: 0.6822 - accuracy: 0.5950 - val_loss: 0.6593 - val_accuracy: 0.6277
# Epoch 2/30
# 42/42 [==============================] - 2s 49ms/step - loss: 0.6645 - accuracy: 0.6176 - val_loss: 0.6572 - val_accuracy: 0.6277
# Epoch 3/30
# 42/42 [==============================] - 2s 49ms/step - loss: 0.6626 - accuracy: 0.6129 - val_loss: 0.6428 - val_accuracy: 0.6277
# Epoch 4/30
# 42/42 [==============================] - 2s 48ms/step - loss: 0.6373 - accuracy: 0.6052 - val_loss: 0.5839 - val_accuracy: 0.7074
# Epoch 5/30
# 42/42 [==============================] - 2s 49ms/step - loss: 0.5571 - accuracy: 0.6973 - val_loss: 0.5559 - val_accuracy: 0.7145
# Epoch 6/30
# 42/42 [==============================] - 2s 49ms/step - loss: 0.5191 - accuracy: 0.7177 - val_loss: 0.5388 - val_accuracy: 0.7216
# Epoch 7/30
# 42/42 [==============================] - 2s 53ms/step - loss: 0.4787 - accuracy: 0.7408 - val_loss: 0.5226 - val_accuracy: 0.7110
# Epoch 8/30
# 42/42 [==============================] - 2s 54ms/step - loss: 0.4814 - accuracy: 0.7291 - val_loss: 0.5123 - val_accuracy: 0.7145
# Epoch 9/30
# 42/42 [==============================] - 2s 60ms/step - loss: 0.4817 - accuracy: 0.7271 - val_loss: 0.5060 - val_accuracy: 0.7199
# Epoch 10/30
# 42/42 [==============================] - 2s 51ms/step - loss: 0.4560 - accuracy: 0.7426 - val_loss: 0.4963 - val_accuracy: 0.7323
# Epoch 11/30
# 42/42 [==============================] - 2s 55ms/step - loss: 0.4395 - accuracy: 0.7484 - val_loss: 0.4914 - val_accuracy: 0.7518
# Epoch 12/30
# 42/42 [==============================] - 3s 62ms/step - loss: 0.4340 - accuracy: 0.7571 - val_loss: 0.4808 - val_accuracy: 0.7482
# Epoch 13/30
# 42/42 [==============================] - 3s 69ms/step - loss: 0.4195 - accuracy: 0.7595 - val_loss: 0.4740 - val_accuracy: 0.7287
# Epoch 14/30
# 42/42 [==============================] - 3s 72ms/step - loss: 0.4045 - accuracy: 0.7756 - val_loss: 0.4622 - val_accuracy: 0.7465
# Epoch 15/30
# 42/42 [==============================] - 3s 78ms/step - loss: 0.4012 - accuracy: 0.7800 - val_loss: 0.4558 - val_accuracy: 0.7553
# Epoch 16/30
# 42/42 [==============================] - 3s 75ms/step - loss: 0.3951 - accuracy: 0.7867 - val_loss: 0.4508 - val_accuracy: 0.7624
# Epoch 17/30
# 42/42 [==============================] - 3s 62ms/step - loss: 0.3731 - accuracy: 0.7997 - val_loss: 0.4467 - val_accuracy: 0.7660
# Epoch 18/30
# 42/42 [==============================] - 3s 68ms/step - loss: 0.3560 - accuracy: 0.8183 - val_loss: 0.4405 - val_accuracy: 0.7677
# Epoch 19/30
# 42/42 [==============================] - 3s 66ms/step - loss: 0.3419 - accuracy: 0.8359 - val_loss: 0.4413 - val_accuracy: 0.7908
# Epoch 20/30
# 42/42 [==============================] - 3s 76ms/step - loss: 0.3305 - accuracy: 0.8389 - val_loss: 0.4295 - val_accuracy: 0.7979
# Epoch 21/30
# 42/42 [==============================] - 4s 88ms/step - loss: 0.3362 - accuracy: 0.8362 - val_loss: 0.4164 - val_accuracy: 0.7979
# Epoch 22/30
# 42/42 [==============================] - 4s 93ms/step - loss: 0.3236 - accuracy: 0.8436 - val_loss: 0.4129 - val_accuracy: 0.7996
# Epoch 23/30
# 42/42 [==============================] - 3s 74ms/step - loss: 0.3185 - accuracy: 0.8459 - val_loss: 0.4157 - val_accuracy: 0.8085
# Epoch 24/30
# 42/42 [==============================] - 3s 69ms/step - loss: 0.3031 - accuracy: 0.8604 - val_loss: 0.4211 - val_accuracy: 0.8138
# Epoch 25/30
# 42/42 [==============================] - 3s 83ms/step - loss: 0.2971 - accuracy: 0.8504 - val_loss: 0.4060 - val_accuracy: 0.8103
# Epoch 26/30
# 42/42 [==============================] - 3s 77ms/step - loss: 0.3049 - accuracy: 0.8468 - val_loss: 0.3991 - val_accuracy: 0.8121
# Epoch 27/30
# 42/42 [==============================] - 3s 78ms/step - loss: 0.2760 - accuracy: 0.8623 - val_loss: 0.4074 - val_accuracy: 0.8156
# Epoch 28/30
# 42/42 [==============================] - 3s 79ms/step - loss: 0.2704 - accuracy: 0.8714 - val_loss: 0.3933 - val_accuracy: 0.8191
# Epoch 29/30
# 42/42 [==============================] - 3s 69ms/step - loss: 0.2715 - accuracy: 0.8721 - val_loss: 0.3927 - val_accuracy: 0.8227
# Epoch 30/30
# 42/42 [==============================] - 4s 85ms/step - loss: 0.2580 - accuracy: 0.8730 - val_loss: 0.3827 - val_accuracy: 0.8191

# %% [markdown]
# **CNN_4_layers_kernel_3**

# %%
model_3 = Sequential()
model_3.add(Conv2D(filters = 3, kernel_size = (3, 3), padding = 'valid', activation = 'relu', input_shape = (128, 128, 1)))
model_3.add(MaxPooling2D())
model_3.add(Conv2D(filters = 3, kernel_size = (3, 3), padding = 'valid', activation = 'relu'))
model_3.add(MaxPooling2D())
model_3.add(Conv2D(filters = 3, kernel_size = (3, 3), padding = 'valid', activation = 'relu'))
model_3.add(MaxPooling2D())
model_3.add(Conv2D(filters = 3, kernel_size = (3, 3), padding = 'valid', activation = 'relu'))
model_3.add(MaxPooling2D())
model_3.add(Flatten())
model_3.add(Dense(units = 2, activation = 'softmax'))

model_3.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
tic = time.perf_counter()
history_3 = model_3.fit(x_train, y_train, epochs = 40, validation_data = (x_test, y_test))
toc = time.perf_counter()

all_results['CNN_4_layers_kernel_3'] = {
    'time': toc-tic,
    'accuracy': history_3.history['accuracy'][-1],
    'val_accuracy': history_3.history['val_accuracy'][-1]
}
# Out:
# Epoch 1/40
# 42/42 [==============================] - 4s 64ms/step - loss: 0.6848 - accuracy: 0.6199 - val_loss: 0.6605 - val_accuracy: 0.6277
# Epoch 2/40
# 42/42 [==============================] - 2s 49ms/step - loss: 0.6672 - accuracy: 0.6134 - val_loss: 0.6589 - val_accuracy: 0.6277
# Epoch 3/40
# 42/42 [==============================] - 2s 49ms/step - loss: 0.6623 - accuracy: 0.6201 - val_loss: 0.6584 - val_accuracy: 0.6277
# Epoch 4/40
# 42/42 [==============================] - 2s 50ms/step - loss: 0.6620 - accuracy: 0.6177 - val_loss: 0.6569 - val_accuracy: 0.6277
# Epoch 5/40
# 42/42 [==============================] - 2s 49ms/step - loss: 0.6638 - accuracy: 0.6094 - val_loss: 0.6517 - val_accuracy: 0.6277
# Epoch 6/40
# 42/42 [==============================] - 2s 50ms/step - loss: 0.6566 - accuracy: 0.6060 - val_loss: 0.6335 - val_accuracy: 0.6277
# Epoch 7/40
# 42/42 [==============================] - 2s 48ms/step - loss: 0.6353 - accuracy: 0.6037 - val_loss: 0.5887 - val_accuracy: 0.7128
# Epoch 8/40
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5594 - accuracy: 0.6984 - val_loss: 0.5773 - val_accuracy: 0.7057
# Epoch 9/40
# 42/42 [==============================] - 2s 51ms/step - loss: 0.5326 - accuracy: 0.7095 - val_loss: 0.5650 - val_accuracy: 0.7110
# Epoch 10/40
# 42/42 [==============================] - 2s 50ms/step - loss: 0.5062 - accuracy: 0.7329 - val_loss: 0.5556 - val_accuracy: 0.7234
# Epoch 11/40
# 42/42 [==============================] - 2s 50ms/step - loss: 0.5022 - accuracy: 0.7326 - val_loss: 0.5516 - val_accuracy: 0.7270
# Epoch 12/40
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5104 - accuracy: 0.7084 - val_loss: 0.5462 - val_accuracy: 0.7163
# Epoch 13/40
# 42/42 [==============================] - 2s 49ms/step - loss: 0.5083 - accuracy: 0.7106 - val_loss: 0.5382 - val_accuracy: 0.7305
# Epoch 14/40
# 42/42 [==============================] - 2s 49ms/step - loss: 0.4789 - accuracy: 0.7428 - val_loss: 0.5327 - val_accuracy: 0.7323
# Epoch 15/40
# 42/42 [==============================] - 2s 49ms/step - loss: 0.4707 - accuracy: 0.7473 - val_loss: 0.5283 - val_accuracy: 0.7340
# Epoch 16/40
# 42/42 [==============================] - 2s 52ms/step - loss: 0.4884 - accuracy: 0.7354 - val_loss: 0.5268 - val_accuracy: 0.7287
# Epoch 17/40
# 42/42 [==============================] - 2s 54ms/step - loss: 0.4648 - accuracy: 0.7530 - val_loss: 0.5154 - val_accuracy: 0.7323
# Epoch 18/40
# 42/42 [==============================] - 2s 48ms/step - loss: 0.4500 - accuracy: 0.7522 - val_loss: 0.5124 - val_accuracy: 0.7305
# Epoch 19/40
# 42/42 [==============================] - 2s 50ms/step - loss: 0.4624 - accuracy: 0.7460 - val_loss: 0.5052 - val_accuracy: 0.7411
# Epoch 20/40
# 42/42 [==============================] - 2s 47ms/step - loss: 0.4392 - accuracy: 0.7525 - val_loss: 0.5006 - val_accuracy: 0.7411
# Epoch 21/40
# 42/42 [==============================] - 2s 50ms/step - loss: 0.4506 - accuracy: 0.7378 - val_loss: 0.4995 - val_accuracy: 0.7411
# Epoch 22/40
# 42/42 [==============================] - 2s 52ms/step - loss: 0.4418 - accuracy: 0.7472 - val_loss: 0.4934 - val_accuracy: 0.7482
# Epoch 23/40
# 42/42 [==============================] - 2s 53ms/step - loss: 0.4170 - accuracy: 0.7677 - val_loss: 0.4864 - val_accuracy: 0.7589
# Epoch 24/40
# 42/42 [==============================] - 2s 48ms/step - loss: 0.4438 - accuracy: 0.7518 - val_loss: 0.4882 - val_accuracy: 0.7571
# Epoch 25/40
# 42/42 [==============================] - 2s 49ms/step - loss: 0.4339 - accuracy: 0.7666 - val_loss: 0.4767 - val_accuracy: 0.7766
# Epoch 26/40
# 42/42 [==============================] - 2s 49ms/step - loss: 0.3927 - accuracy: 0.7937 - val_loss: 0.4721 - val_accuracy: 0.7784
# Epoch 27/40
# 42/42 [==============================] - 2s 50ms/step - loss: 0.4277 - accuracy: 0.7560 - val_loss: 0.4746 - val_accuracy: 0.7695
# Epoch 28/40
# 42/42 [==============================] - 2s 50ms/step - loss: 0.4001 - accuracy: 0.7792 - val_loss: 0.4658 - val_accuracy: 0.7748
# Epoch 29/40
# 42/42 [==============================] - 2s 54ms/step - loss: 0.3964 - accuracy: 0.7788 - val_loss: 0.4597 - val_accuracy: 0.7837
# Epoch 30/40
# 42/42 [==============================] - 2s 52ms/step - loss: 0.3847 - accuracy: 0.7975 - val_loss: 0.4624 - val_accuracy: 0.7801
# Epoch 31/40
# 42/42 [==============================] - 2s 55ms/step - loss: 0.3923 - accuracy: 0.7939 - val_loss: 0.4530 - val_accuracy: 0.7943
# Epoch 32/40
# 42/42 [==============================] - 2s 50ms/step - loss: 0.4008 - accuracy: 0.7810 - val_loss: 0.4585 - val_accuracy: 0.7890
# Epoch 33/40
# 42/42 [==============================] - 3s 61ms/step - loss: 0.3817 - accuracy: 0.7970 - val_loss: 0.4453 - val_accuracy: 0.7943
# Epoch 34/40
# 42/42 [==============================] - 2s 54ms/step - loss: 0.3833 - accuracy: 0.7988 - val_loss: 0.4501 - val_accuracy: 0.7908
# Epoch 35/40
# 42/42 [==============================] - 2s 52ms/step - loss: 0.3695 - accuracy: 0.8010 - val_loss: 0.4416 - val_accuracy: 0.7890
# Epoch 36/40
# 42/42 [==============================] - 2s 55ms/step - loss: 0.3924 - accuracy: 0.7939 - val_loss: 0.4406 - val_accuracy: 0.7979
# Epoch 37/40
# 42/42 [==============================] - 3s 64ms/step - loss: 0.3620 - accuracy: 0.7933 - val_loss: 0.4282 - val_accuracy: 0.8085
# Epoch 38/40
# 42/42 [==============================] - 3s 82ms/step - loss: 0.3703 - accuracy: 0.8161 - val_loss: 0.4415 - val_accuracy: 0.7961
# Epoch 39/40
# 42/42 [==============================] - 4s 87ms/step - loss: 0.3624 - accuracy: 0.8203 - val_loss: 0.4220 - val_accuracy: 0.8032
# Epoch 40/40
# 42/42 [==============================] - 3s 68ms/step - loss: 0.3648 - accuracy: 0.8104 - val_loss: 0.4170 - val_accuracy: 0.8227

# %% [markdown]
# **CNN_2_layers_kernel_5**

# %%
model_4 = Sequential()
model_4.add(Conv2D(filters = 5, kernel_size = (5, 5), padding = 'valid', activation = 'relu', input_shape = (128, 128, 1)))
model_4.add(MaxPooling2D())
model_4.add(Conv2D(filters = 5, kernel_size = (5, 5), padding = 'valid', activation = 'relu'))
model_4.add(MaxPooling2D())
model_4.add(Flatten())
model_4.add(Dense(units = 2, activation = 'softmax'))

model_4.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
tic = time.perf_counter()
history_4 = model_4.fit(x_train, y_train, epochs = 50, validation_data = (x_test, y_test))
toc = time.perf_counter()

all_results['CNN_2_layers_kernel_5'] = {
    'time': toc-tic,
    'accuracy': history_4.history['accuracy'][-1],
    'val_accuracy': history_4.history['val_accuracy'][-1]
}
# Out:
# Epoch 1/50
# 42/42 [==============================] - 5s 105ms/step - loss: 0.6730 - accuracy: 0.5774 - val_loss: 0.6218 - val_accuracy: 0.6277
# Epoch 2/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.5907 - accuracy: 0.6826 - val_loss: 0.5472 - val_accuracy: 0.7110
# Epoch 3/50
# 42/42 [==============================] - 4s 91ms/step - loss: 0.5211 - accuracy: 0.7154 - val_loss: 0.5317 - val_accuracy: 0.7145
# Epoch 4/50
# 42/42 [==============================] - 4s 92ms/step - loss: 0.4879 - accuracy: 0.7140 - val_loss: 0.5160 - val_accuracy: 0.7305
# Epoch 5/50
# 42/42 [==============================] - 4s 90ms/step - loss: 0.4597 - accuracy: 0.7317 - val_loss: 0.4989 - val_accuracy: 0.7305
# Epoch 6/50
# 42/42 [==============================] - 4s 88ms/step - loss: 0.4517 - accuracy: 0.7486 - val_loss: 0.4879 - val_accuracy: 0.7429
# Epoch 7/50
# 42/42 [==============================] - 4s 90ms/step - loss: 0.4136 - accuracy: 0.7767 - val_loss: 0.4753 - val_accuracy: 0.7411
# Epoch 8/50
# 42/42 [==============================] - 4s 88ms/step - loss: 0.4111 - accuracy: 0.7876 - val_loss: 0.4655 - val_accuracy: 0.7890
# Epoch 9/50
# 42/42 [==============================] - 4s 88ms/step - loss: 0.3690 - accuracy: 0.8157 - val_loss: 0.4481 - val_accuracy: 0.7926
# Epoch 10/50
# 42/42 [==============================] - 4s 92ms/step - loss: 0.3579 - accuracy: 0.8140 - val_loss: 0.4587 - val_accuracy: 0.7465
# Epoch 11/50
# 42/42 [==============================] - 4s 89ms/step - loss: 0.3693 - accuracy: 0.7890 - val_loss: 0.4288 - val_accuracy: 0.7872
# Epoch 12/50
# 42/42 [==============================] - 4s 87ms/step - loss: 0.3316 - accuracy: 0.8245 - val_loss: 0.4251 - val_accuracy: 0.8174
# Epoch 13/50
# 42/42 [==============================] - 4s 87ms/step - loss: 0.3211 - accuracy: 0.8510 - val_loss: 0.4253 - val_accuracy: 0.8050
# Epoch 14/50
# 42/42 [==============================] - 4s 86ms/step - loss: 0.2832 - accuracy: 0.8736 - val_loss: 0.4071 - val_accuracy: 0.8262
# Epoch 15/50
# 42/42 [==============================] - 4s 88ms/step - loss: 0.2534 - accuracy: 0.8978 - val_loss: 0.3999 - val_accuracy: 0.8369
# Epoch 16/50
# 42/42 [==============================] - 4s 88ms/step - loss: 0.2435 - accuracy: 0.9100 - val_loss: 0.3978 - val_accuracy: 0.8440
# Epoch 17/50
# 42/42 [==============================] - 4s 87ms/step - loss: 0.2166 - accuracy: 0.9156 - val_loss: 0.3779 - val_accuracy: 0.8387
# Epoch 18/50
# 42/42 [==============================] - 4s 87ms/step - loss: 0.2026 - accuracy: 0.9334 - val_loss: 0.3618 - val_accuracy: 0.8582
# Epoch 19/50
# 42/42 [==============================] - 4s 96ms/step - loss: 0.1946 - accuracy: 0.9472 - val_loss: 0.4671 - val_accuracy: 0.8227
# Epoch 20/50
# 42/42 [==============================] - 4s 98ms/step - loss: 0.1769 - accuracy: 0.9409 - val_loss: 0.3675 - val_accuracy: 0.8652
# Epoch 21/50
# 42/42 [==============================] - 5s 109ms/step - loss: 0.1428 - accuracy: 0.9643 - val_loss: 0.3750 - val_accuracy: 0.8599
# Epoch 22/50
# 42/42 [==============================] - 5s 110ms/step - loss: 0.1603 - accuracy: 0.9350 - val_loss: 0.3562 - val_accuracy: 0.8670
# Epoch 23/50
# 42/42 [==============================] - 6s 133ms/step - loss: 0.1351 - accuracy: 0.9628 - val_loss: 0.3940 - val_accuracy: 0.8582
# Epoch 24/50
# 42/42 [==============================] - 4s 103ms/step - loss: 0.1476 - accuracy: 0.9490 - val_loss: 0.3561 - val_accuracy: 0.8741
# Epoch 25/50
# 42/42 [==============================] - 5s 112ms/step - loss: 0.0958 - accuracy: 0.9862 - val_loss: 0.3850 - val_accuracy: 0.8688
# Epoch 26/50
# 42/42 [==============================] - 5s 111ms/step - loss: 0.0921 - accuracy: 0.9871 - val_loss: 0.3656 - val_accuracy: 0.8794
# Epoch 27/50
# 42/42 [==============================] - 6s 141ms/step - loss: 0.0901 - accuracy: 0.9837 - val_loss: 0.3793 - val_accuracy: 0.8777
# Epoch 28/50
# 42/42 [==============================] - 5s 120ms/step - loss: 0.0986 - accuracy: 0.9748 - val_loss: 0.4326 - val_accuracy: 0.8493
# Epoch 29/50
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0938 - accuracy: 0.9803 - val_loss: 0.3557 - val_accuracy: 0.8883
# Epoch 30/50
# 42/42 [==============================] - 5s 123ms/step - loss: 0.0772 - accuracy: 0.9847 - val_loss: 0.3687 - val_accuracy: 0.8865
# Epoch 31/50
# 42/42 [==============================] - 5s 119ms/step - loss: 0.0721 - accuracy: 0.9831 - val_loss: 0.3802 - val_accuracy: 0.8972
# Epoch 32/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.0759 - accuracy: 0.9883 - val_loss: 0.4052 - val_accuracy: 0.8759
# Epoch 33/50
# 42/42 [==============================] - 4s 93ms/step - loss: 0.0599 - accuracy: 0.9864 - val_loss: 0.4179 - val_accuracy: 0.8706
# Epoch 34/50
# 42/42 [==============================] - 4s 94ms/step - loss: 0.0503 - accuracy: 0.9914 - val_loss: 0.3660 - val_accuracy: 0.8918
# Epoch 35/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.0404 - accuracy: 0.9970 - val_loss: 0.3844 - val_accuracy: 0.8901
# Epoch 36/50
# 42/42 [==============================] - 4s 105ms/step - loss: 0.0392 - accuracy: 0.9969 - val_loss: 0.3786 - val_accuracy: 0.8972
# Epoch 37/50
#  3/42 [=>............................] - ETA: 5s - loss: 0.0332 - accuracy: 1.0000

# %% [markdown]
# **CNN_3_layers_kernel_5**

# %%
model_5 = Sequential()
model_5.add(Conv2D(filters = 5, kernel_size = (5, 5), padding = 'valid', activation = 'relu', input_shape = (128, 128, 1)))
model_5.add(MaxPooling2D())
model_5.add(Conv2D(filters = 5, kernel_size = (5, 5), padding = 'valid', activation = 'relu'))
model_5.add(MaxPooling2D())
model_5.add(Conv2D(filters = 5, kernel_size = (5, 5), padding = 'valid', activation = 'relu'))
model_5.add(MaxPooling2D())
model_5.add(Flatten())
model_5.add(Dense(units = 2, activation = 'softmax'))

model_5.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
tic = time.perf_counter()
history_5 = model_5.fit(x_train, y_train, epochs = 60, validation_data = (x_test, y_test))
toc = time.perf_counter()

all_results['CNN_3_layers_kernel_5'] = {
    'time': toc-tic,
    'accuracy': history_5.history['accuracy'][-1],
    'val_accuracy': history_5.history['val_accuracy'][-1]
}

# %% [markdown]
# **CNN_4_layers_kernel_5**

# %%
model_6 = Sequential()
model_6.add(Conv2D(filters = 5, kernel_size = (5, 5), padding = 'valid', activation = 'relu', input_shape = (128, 128, 1)))
model_6.add(MaxPooling2D())
model_6.add(Conv2D(filters = 5, kernel_size = (5, 5), padding = 'valid', activation = 'relu'))
model_6.add(MaxPooling2D())
model_6.add(Conv2D(filters = 5, kernel_size = (5, 5), padding = 'valid', activation = 'relu'))
model_6.add(MaxPooling2D())
model_6.add(Conv2D(filters = 5, kernel_size = (5, 5), padding = 'valid', activation = 'relu'))
model_6.add(MaxPooling2D())
model_6.add(Flatten())
model_6.add(Dense(units = 2, activation = 'softmax'))

model_6.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
tic = time.perf_counter()
history_6 = model_6.fit(x_train, y_train, epochs = 70, validation_data = (x_test, y_test))
toc = time.perf_counter()

all_results['CNN_4_layers_kernel_5'] = {
    'time': toc-tic,
    'accuracy': history_6.history['accuracy'][-1],
    'val_accuracy': history_6.history['val_accuracy'][-1]
}

# %% [markdown]
# **CNN_4_layers_kernel_5_moreFC**

# %%
model_7 = Sequential()
model_7.add(Conv2D(filters = 5, kernel_size = (5, 5), padding = 'valid', activation = 'relu', input_shape = (128, 128, 1)))
model_7.add(MaxPooling2D())
model_7.add(Conv2D(filters = 5, kernel_size = (5, 5), padding = 'valid', activation = 'relu'))
model_7.add(MaxPooling2D())
model_7.add(Conv2D(filters = 5, kernel_size = (5, 5), padding = 'valid', activation = 'relu'))
model_7.add(MaxPooling2D())
model_7.add(Conv2D(filters = 5, kernel_size = (5, 5), padding = 'valid', activation = 'relu'))
model_7.add(MaxPooling2D())
model_7.add(Flatten())
model_7.add(Dense(units = 16, activation = 'relu'))
model_7.add(Dense(units = 4, activation = 'relu'))
model_7.add(Dense(units = 2, activation = 'softmax'))

model_7.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
tic = time.perf_counter()
history_7 = model_7.fit(x_train, y_train, epochs = 70, validation_data = (x_test, y_test))
toc = time.perf_counter()

all_results['CNN_4_layers_kernel_5_moreFC'] = {
    'time': toc-tic,
    'accuracy': history_7.history['accuracy'][-1],
    'val_accuracy': history_7.history['val_accuracy'][-1]
}

# %%
all_results

# %%
pd.DataFrame(all_results).filter(regex = '.*kernel_3')

# %%
pd.DataFrame(all_results).filter(regex = '.*kernel_5')

# %%
model_7.summary()

# %%
from tensorflow.keras.applications import VGG16, InceptionV3, ResNet50

# %%
inbuilt_results = dict()

# %% [markdown]
# **VGG16**

# %%
vgg_model = VGG16(weights = None, input_shape = (128, 128, 1), classes = 2)
vgg_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
x_vgg = tf.keras.applications.vgg16.preprocess_input(x)
x_vgg_train, x_vgg_test, y_train, y_test = train_test_split(x_vgg, y, test_size = 0.3)
tic = time.perf_counter()
vgg_history = vgg_model.fit(x_vgg_train, y_train, epochs = 15, validation_data = (x_vgg_test, y_test))
toc = time.perf_counter()

inbuilt_results['VGG16'] = {
    'time': toc-tic,
    'accuracy': vgg_history.history['accuracy'][-1],
    'val_accuracy': vgg_history.history['val_accuracy'][-1]
}

# %% [markdown]
# **InceptionV3**

# %%
inception_model = InceptionV3(weights = None, input_shape = (128, 128, 1), classes = 2)
inception_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
x_inception = tf.keras.applications.inception_v3.preprocess_input(x)
x_inception_train, x_inception_test, y_train, y_test = train_test_split(x_inception, y, test_size = 0.3)
tic = time.perf_counter()
inception_history = inception_model.fit(x_inception_train, y_train, epochs = 15,  validation_data = (x_inception_test, y_test))
toc = time.perf_counter()

inbuilt_results['InceptionV3'] = {
    'time': toc-tic,
    'accuracy': inception_history.history['accuracy'][-1],
    'val_accuracy': inception_history.history['val_accuracy'][-1]
}

# %% [markdown]
# **ResNet50**

# %%
resnet_model = ResNet50(weights = None, input_shape = (128, 128, 1), classes = 2)
resnet_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
x_resnet = tf.keras.applications.resnet.preprocess_input(x)
x_resnet_train, x_resnet_test, y_train, y_test = train_test_split(x_resnet, y, test_size = 0.3)
tic = time.perf_counter()
resnet_history = resnet_model.fit(x_resnet_train, y_train, epochs = 15, validation_data = (x_resnet_test, y_test))
toc = time.perf_counter()

inbuilt_results['ResNet50'] = {
    'time': toc-tic,
    'accuracy': resnet_history.history['accuracy'][-1],
    'val_accuracy': resnet_history.history['val_accuracy'][-1]
}

# %%
pd.DataFrame(inbuilt_results)
