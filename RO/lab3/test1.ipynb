# %%
from time import time
import logging
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import fetch_lfw_people
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
from sklearn.svm import SVC

from skimage import io
from skimage.color import rgb2gray
import numpy as np
from pathlib import Path
from skimage.transform import resize, rescale


DATA_DIR = 'data/djenifer_lorens/'

images = np.array([resize(rgb2gray(io.imread(file)), (250, 188)) for file in Path.cwd().glob(f'{DATA_DIR}*')])

n_samples, h, w = images.shape

X = np.array([img.reshape(h * w) for img in images])
n_features = X.shape[1]

y = np.zeros(X.shape[0])
target_names = np.array(['Djenifer Lorens', ])
n_classes = target_names.shape[0]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

lfw_people = fetch_lfw_people(min_faces_per_person=70, resize=2)
for img in lfw_people.images[:10]:
    plt.figure()
    plt.imshow(img)

for img in images[:10]:
    plt.figure()
    plt.imshow(img)
# Out:
# <ipython-input-1-aa34ac947008>:22: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   images = np.array([resize(rgb2gray(io.imread(file)), (250, 188)) for file in Path.cwd().glob(f'{DATA_DIR}*')])
# (250, 188)
# (250, 188)
# (250, 188)
# (250, 188)
# (250, 188)
# (250, 188)
# (250, 188)
# (250, 188)
# (250, 188)
# (250, 188)
